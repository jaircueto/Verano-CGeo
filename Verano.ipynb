# %%
using PyPlot
using Plots

# %%
;ls
# Out:
# CMTMex.txt
# CMTVerano.ipynb
# Verano.ipynb

# %%
data  = readdlm("CMTMex.txt")
# Out:
# 994×10 Array{Float64,2}:
#   -89.78  15.14  1976.09   2.0   4.0  7.47   16.3   9.0   2.0   7.19998
#  -100.91  17.22  1976.43   6.0   7.0  6.42   29.0  14.0  26.0  43.2
#   -93.12  16.56  1977.25   4.0   2.0  5.51  209.7  20.0  39.0   7.40001
#   -86.65  16.61  1977.63   8.0  20.0  6.07   40.2   2.0  46.0  15.9
#   -86.95  16.71  1977.63   8.0  20.0  6.32   38.2   3.0  51.0  57.6
#   -88.22  12.27  1977.67   9.0   3.0  5.66   42.3  22.0  33.0   7.2
#   -92.16  13.46  1977.69   9.0  10.0  5.49   15.0  10.0  21.0   7.3
#   -91.72  13.72  1978.14   2.0  19.0  5.61   45.8  19.0  42.0  45.3
#   -91.75  13.46  1978.14   2.0  22.0  6.29   72.7   6.0   7.0  33.4
#   -99.86  17.15  1978.21   3.0  19.0  6.57   11.0   1.0  39.0  31.3
#   -92.66  13.77  1978.36   5.0  11.0  5.46   41.2  23.0  18.0  22.7
#   -87.19  12.43  1978.41   5.0  31.0  6.5    40.3   1.0   7.0  28.7
#  -100.74  18.05  1978.51   7.0   5.0  5.55   60.2  20.0  15.0  24.3
#     ⋮                                 ⋮
# ...

# %%
plot(data[:,3],data[:,6],".",color="blue");
title("Sismos 1976-2016");
xlabel("Tiempo en años");
ylabel("Magnitud");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f5d831fe410>)

# %%
plot(data[:,1],data[:,2],".",color="red");
title("Sismos en México 1976-2016");
xlabel("Longitud");
ylabel("Latitud");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f5d7ec1acd0>)

# %%
histogram(data[:,6])
#Caja de 0.1
# Out:
# <img src="data:image/png;base64,..." />

# %%
histogram(data[:,7])
# Out:
# <img src="data:image/png;base64,..." />
